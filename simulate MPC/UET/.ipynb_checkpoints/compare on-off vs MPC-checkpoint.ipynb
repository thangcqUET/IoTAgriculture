# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure

soilMoistureFolowTimeByONOFF=pd.read_csv("soil_moisture_on_off.csv")
soilMoistureFolowTimeByMPC = pd.read_csv("soil_moisture_MPC.csv")

# %%
sumTimeOnOff=[]
sumTimeOnOff.append(soilMoistureFolowTimeByONOFF['amount of watering'][0])
for i in range(1,len(soilMoistureFolowTimeByONOFF['amount of watering'])):
    sumTimeOnOff.append(sumTimeOnOff[i-1]+soilMoistureFolowTimeByONOFF['amount of watering'][i])

# %%
sumTimeMPC=[]
sumTimeMPC.append(soilMoistureFolowTimeByMPC['amount of watering'][0])
for i in range(1,len(soilMoistureFolowTimeByMPC['amount of watering'])):
    sumTimeMPC.append(sumTimeMPC[i-1]+soilMoistureFolowTimeByMPC['amount of watering'][i])

# %%
figure(num=None, figsize=(10, 5), dpi=500, facecolor='w', edgecolor='k')
plt.plot(pd.to_datetime(soilMoistureFolowTimeByONOFF['datetime']),sumTimeOnOff)
plt.plot(pd.to_datetime(soilMoistureFolowTimeByMPC['datetime']),sumTimeMPC)
plt.title('Tổng thời lượng tưới nước giữa 2 phương pháp tưới On/Off và MPC')
plt.legend(['On/Off','MPC'])
plt.xlabel('thời gian')
plt.ylabel('tổng thời lượng tưới nước (s)')
# Out:
# Text(0,0.5,'tổng thời lượng tưới nước (s)')

# %%
# Out:
# 0    2020-05-03 06:00:00.000000
# 1    2020-05-03 07:00:00.000000
# 2    2020-05-03 08:00:00.000000
# 3    2020-05-03 09:00:00.000000
# 4    2020-05-03 10:00:00.000000
# 5    2020-05-03 10:00:08.426154
# 6    2020-05-03 11:00:00.000000
# 7    2020-05-03 12:00:00.000000
# 8    2020-05-03 13:00:00.000000
# 9    2020-05-03 14:00:00.000000
# 10   2020-05-03 15:00:00.000000
# 11   2020-05-03 16:00:00.000000
# 12   2020-05-03 17:00:00.000000
# 13   2020-05-03 18:00:00.000000
# 14   2020-05-03 19:00:00.000000
# 15   2020-05-03 20:00:00.000000
# 16   2020-05-03 21:00:00.000000
# 17   2020-05-03 21:00:08.962084
# 18   2020-05-03 22:00:00.000000
# 19   2020-05-03 23:00:00.000000
# 20   2020-05-04 00:00:00.000000
# 21   2020-05-04 01:00:00.000000
# 22   2020-05-04 02:00:00.000000
# 23   2020-05-04 03:00:00.000000
# 24   2020-05-04 04:00:00.000000
# 25   2020-05-04 04:00:08.710486
# 26   2020-05-04 05:00:00.000000
# Name: datetime, dtype: datetime64[ns]
